# %% [markdown]
# # Hand Gesture Modeling using TFLite Model Maker
#
#
# ---

# %% [markdown]
# ### Install the required packages
# Start by installing the required packages, including the Model Maker package from the [GitHub repo](https://github.com/tensorflow/examples/tree/master/tensorflow_examples/lite/model_maker) and the pycocotools library you'll use for evaluation.

# %%
# !sudo apt -y install libportaudio2
# !pip install -q --use-deprecated=legacy-resolver tflite-model-maker
# !pip install -q pycocotools
# !pip install -q opencv-python-headless==4.1.2.30
# !pip uninstall -y tensorflow && pip install -q tensorflow==2.8.0
# !pip install -q mycolorpy

# %% [markdown]
# ### Import the required packages.

# %%
import numpy as np
import os
import pandas as pd
import seaborn as sns
from mycolorpy import colorlist as mcp
import numpy as np

from tflite_model_maker.config import QuantizationConfig
from tflite_model_maker.config import ExportFormat
from tflite_model_maker import model_spec
from tflite_model_maker import object_detector
import xml.etree.ElementTree as ET
import os
import matplotlib.pyplot as plt
from random import randrange
import numpy as np
from matplotlib.colors import hsv_to_rgb, to_hex
from PIL import Image, ImageDraw, ImageFont
from matplotlib.pyplot import figure

import tensorflow as tf
assert tf.__version__.startswith('2')

tf.get_logger().setLevel('ERROR')
from absl import logging
logging.set_verbosity(logging.ERROR)

import warnings
warnings.filterwarnings("ignore")

#mount your google drive if you use hosted runtime
#from google.colab import drive
#drive.mount('/content/drive')

# %%
def draw_image(image, results, size):
    result_size = len(results)
    for idx, obj in enumerate(results):
        # Prepare image for drawing
        draw = ImageDraw.Draw(image)

        # Prepare boundary box
        xmin, ymin, xmax, ymax = obj['bounding_box']
        xmin = int(xmin * size[1])
        xmax = int(xmax * size[1])
        ymin = int(ymin * size[0])
        ymax = int(ymax * size[0])

        #print(size)

        # Draw rectangle to desired thickness
        for x in range( 0, 10 ):
            color = tuple(np.random.choice(range(256), size=3))
            draw.rectangle((ymin, xmin, ymax, xmax), outline=color, width=5)
        display_str = labels[obj['class_id']] + ": " + str(round(obj['score']*100, 2)) + "%"
        draw.rectangle((ymin+5, xmin+10, ymin+len(display_str)*10, xmin+35), fill='black')
        draw.text((ymin+10,xmin+15), display_str)#, font=ImageFont.truetype("./utils/Neusharp-Bold.otf", 16))

    displayImage = np.asarray( image )
    #display(Image.fromarray(displayImage))
    st.image(displayImage)

# %% [markdown]
# ### Create Dataframe from Images & PascalVOC Annotations (from `LabelImg`)
#
# #### Training Set

# %%
# training set
df_train = pd.DataFrame(columns=['type','path','label','XMin','YMin','XMax','YMax'])
df_train.head()

# path to the image files
path_to_images = "your_own_path/data_for_object_detection/data/"

# path to the annotation files (in xml format)
directory_in_str = "your_own_path/data_for_object_detection/xml/"
directory = os.fsencode(directory_in_str)

for file in os.listdir(directory):
    filename = os.fsdecode(file)

    if filename.endswith(".xml"):
        name = os.path.splitext(filename)[0]
        path = directory_in_str + filename
        
        # X divided by the width
        # Y divided by the height
        # how to calculate normalized coordinates: https://stackoverflow.com/questions/48915003/get-the-bounding-box-coordinates-in-the-tensorflow-object-detection-api-tutorial

        tree = ET.parse(path)
        root = tree.getroot()
        image_name = path_to_images + root.find('filename').text
        
        for size in root.findall('size'):
            width = int(size.find('width').text)
            height = int(size.find('height').text)
            
        for object in root.findall('object'):
            label_type = object.find('name').text
            for bndbox in object.findall('bndbox'):
                xmin = int(bndbox.find('xmin').text) / width
                xmax = int(bndbox.find('xmax').text) / width
                ymin = int(bndbox.find('ymin').text) / height
                ymax = int(bndbox.find('ymax').text) / height
                
                new_row = {
                 'type':"TRAIN",
                 'path':image_name,
                 'label':label_type,
                 'XMin':xmin,
                 'YMin':ymin,
                 'XMax':xmax,
                 'YMax':ymax,
                 }

                df_train = df_train.append(new_row, ignore_index=True)

df_train.head(2)
# Out:
#     type                                               path    label    XMin  \
# 0  TRAIN  F:/Downloads/projects/hand-gestures/data_for_o...  option3  0.7365
# 1  TRAIN  F:/Downloads/projects/hand-gestures/data_for_o...  option3  0.2470
#
#        YMin    XMax      YMax
# 0  0.274536  0.8210  0.526525
# 1  0.365341  0.4655  0.880720

# %%
# check the number of annotations in each train class
df_train.label.value_counts().to_frame()
# Out:
#          label
# option3    101
# back       100
# ok         100
# option1    100
# option2    100
# option4    100
# thumb      100
# punch      100

# %% [markdown]
# ### Testing Set

# %%
# test set
df_test = pd.DataFrame(columns=['type','path','label','XMin','YMin','XMax','YMax'])
df_test.head()

# path to the images file of test set
path_to_images = "your_path/data_for_object_detection/test/data/"

# path to the annotation files (in xml format) of test set
directory_in_str = "your_path/data_for_object_detection/test/xml/"
directory = os.fsencode(directory_in_str)

for file in os.listdir(directory):
    filename = os.fsdecode(file)

    if filename.endswith(".xml"):
        name = os.path.splitext(filename)[0]
        path = directory_in_str + filename

        tree = ET.parse(path)
        root = tree.getroot()
        image_name = path_to_images + root.find('filename').text
        
        for size in root.findall('size'):
            width = int(size.find('width').text)
            height = int(size.find('height').text)
            
        for object in root.findall('object'):
            label_type = object.find('name').text
            for bndbox in object.findall('bndbox'):
                xmin = int(bndbox.find('xmin').text) / width
                xmax = int(bndbox.find('xmax').text) / width
                ymin = int(bndbox.find('ymin').text) / height
                ymax = int(bndbox.find('ymax').text) / height
                
                new_row = {
                 'type':"TRAIN",
                 'path':image_name,
                 'label':label_type,
                 'XMin':xmin,
                 'YMin':ymin,
                 'XMax':xmax,
                 'YMax':ymax,
                 }

                df_test = df_test.append(new_row, ignore_index=True)

df_test.head(2)
# Out:
#     type                                               path label      XMin  \
# 0  TRAIN  F:/Downloads/projects/hand-gestures/data_for_o...    ok  0.183007
# 1  TRAIN  F:/Downloads/projects/hand-gestures/data_for_o...  back  0.081913
#
#        YMin      XMax      YMax
# 0  0.238562  0.375817  0.477124
# 1  0.083843  0.979030  0.748472

# %%
# check the number of annotations in each test class
df_test.label.value_counts().to_frame()
# Out:
#          label
# ok          10
# back        10
# option4     10
# option2     10
# option1     10
# option3     10
# thumb       10
# punch       10

# %%
print("Total Number of Images:\n=======================\nTrain Set: {}\nTest Set: {}".format(df_train['type'].count(), df_test['type'].count()))
# Out:
# Total Number of Images:
# =======================
# Train Set: 801
# Test Set: 80

# %%
# rand_col: function to get a random color
def rand_col(min_v=0.5, max_v=1.0):
    hsv = np.concatenate([np.random.rand(2), np.random.uniform(min_v, max_v, size=1)])
    return to_hex(hsv_to_rgb(hsv))

# %%
# draw_image: function to draw image along with its bounding box
def draw_image(image_path, xmin, xmax, ymin, ymax, label):
  image = Image.open(image_path).convert('RGB')

  width, height = image.size
  new_height = 500
  new_width  = new_height * width / height

  image = image.resize((int(new_width), int(new_height)), Image.ANTIALIAS)
  draw = ImageDraw.Draw(image)

  xmin = xmin*new_width
  xmax = xmax*new_width
  ymin = ymin*new_height
  ymax = ymax*new_height
  color = rand_col(min_v=1)

  for x in range( 0, 10 ):
    draw.rectangle((xmin, ymin, xmax, ymax), outline=color, width=5)
  display_str = label

  fontsize = 10
  font = ImageFont.truetype('F:/Downloads/projects/Roboto-Medium.ttf', fontsize)
  img_fraction = 0.3
  breakpoint = img_fraction * new_width
  jumpsize = 2
  while True:
      if font.getsize(label)[0] < breakpoint:
          fontsize += jumpsize
      else:
          jumpsize = jumpsize // 2
          fontsize -= jumpsize
      font = ImageFont.truetype('F:/Downloads/projects/Roboto-Medium.ttf', fontsize)
      if jumpsize <= 1:
          break

  draw.text((ymin,xmin), display_str, font=font,fill=color)
  displayImage = np.asarray( image )
  return displayImage

# %%
fig, axes = plt.subplots(nrows=2, ncols=8, figsize=(25, 8),
                        subplot_kw={'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):
  img = df_pascal.iloc[randrange(len(df_pascal)-1)]
  image = draw_image(img['path'], img['XMin'], img['XMax'], img['YMin'], img['YMax'], img['label'])
  ax.imshow(image)

# %% [markdown]
# ## Model Training

# %% [markdown]
# There are six steps to training an object detection model:
#
# **Step 1. Choose an object detection model archiecture.**
#
# This tutorial uses the EfficientDet-Lite0 model. EfficientDet-Lite[0-4] are a family of mobile/IoT-friendly object detection models derived from the [EfficientDet](https://arxiv.org/abs/1911.09070) architecture.
#
# Here is the performance of each EfficientDet-Lite models compared to each others.
#
# | Model architecture | Size(MB)* | Latency(ms)** | Average Precision*** |
# |--------------------|-----------|---------------|----------------------|
# | EfficientDet-Lite0 | 4.4       | 37            | 25.69%               |
# | EfficientDet-Lite1 | 5.8       | 49            | 30.55%               |
# | EfficientDet-Lite2 | 7.2       | 69            | 33.97%               |
# | EfficientDet-Lite3 | 11.4      | 116           | 37.70%               |
# | EfficientDet-Lite4 | 19.9      | 260           | 41.96%               |
#
# <i> * Size of the integer quantized models. <br/>
# ** Latency measured on Pixel 4 using 4 threads on CPU. <br/>
# *** Average Precision is the mAP (mean Average Precision) on the COCO 2017 validation dataset.
# </i>

# %%
spec_lite0 = model_spec.get('efficientdet_lite0')
spec_lite1 = model_spec.get('efficientdet_lite1')
spec_lite2 = model_spec.get('efficientdet_lite2')
spec_lite3 = model_spec.get('efficientdet_lite3')
spec_lite4 = model_spec.get('efficientdet_lite4')

# %% [markdown]
# **Step 2. Load the dataset.**
#
# Model Maker can take input data in the CSV format. However, since we used LabelImg for annotations, we can specify the `DataLoader` to use the PascalVOC format. Use the `object_detector.DataLoader.from_pascal_voc` method to load the dataset and split them into the training, validation and test images.
#
# * Training images: These images are used to train the object detection model to recognize salad ingredients.
# * Validation images: These are images that the model didn't see during the training process. You'll use them to decide when you should stop the training, to avoid [overfitting](https://en.wikipedia.org/wiki/Overfitting). This is not included in our training but you can include it, same procedure as train & test set.
# * Test images: These images are used to evaluate the final model performance.
#
# Simply specify the path to your images and annotations for your training & testing data.

# %%
# check current working directory
os.getcwd()
# Out:
# 'F:\\Downloads'

# %% [markdown]
# ### Load the Train Set

# %%
path_to_train_images = 'your_path/data_for_object_detection/data'
path_to_train_xml = 'your_path/data_for_object_detection/xml'

train_data = object_detector.DataLoader.from_pascal_voc(path_to_train_images, path_to_train_xml,
                                                                   label_map={1: "option1",
                                                                              2: "option2",
                                                                              3: "option3",
                                                                              4: "option4",
                                                                              5: "punch",
                                                                              6: "thumb",
                                                                              7: "ok",
                                                                              8: "back"})

# %%
# check the number of images in your train dataset, as long as it is not 0, you are good
train_data.size
# Out:
# 801

# %% [markdown]
# ### Load the Test Set

# %%
path_to_test_images = 'your_path/data_for_object_detection/test/data'
path_to_test_xml = 'your_path/data_for_object_detection/test/xml'

test_data = object_detector.DataLoader.from_pascal_voc(path_to_test_images, path_to_test_xml,
                                                                   label_map={1: "option1",
                                                                              2: "option2",
                                                                              3: "option3",
                                                                              4: "option4",
                                                                              5: "punch",
                                                                              6: "thumb",
                                                                              7: "ok",
                                                                              8: "back"})

# %%
# check the number of images in your test dataset
test_data.size
# Out:
# 79

# %% [markdown]
# **Step 3. Train the TensorFlow model with the training data.**
#
# * The EfficientDet-Lite0 model uses `epochs = 50` by default, which means it will go through the training dataset 50 times. You can look at the validation accuracy during training and stop early to avoid overfitting.
# * Set `batch_size = 8` here so you will see that it takes 100 steps to go through the 801 images in the training dataset.
# * Set `train_whole_model=True` to fine-tune the whole model instead of just training the head layer to improve accuracy. The trade-off is that it may take longer to train the model.

# %%
lite0 = object_detector.create(train_data, model_spec=spec_lite0, batch_size=8, train_whole_model=True)
# Out:
# Epoch 1/50
# 100/100 [==============================] - 35s 212ms/step - det_loss: 1.4762 - cls_loss: 1.0656 - box_loss: 0.0082 - reg_l2_loss: 0.0641 - loss: 1.5403 - learning_rate: 0.0090 - gradient_norm: 2.0538
# Epoch 2/50
# 100/100 [==============================] - 19s 185ms/step - det_loss: 0.8982 - cls_loss: 0.7096 - box_loss: 0.0038 - reg_l2_loss: 0.0642 - loss: 0.9624 - learning_rate: 0.0100 - gradient_norm: 3.2183
# Epoch 3/50
# 100/100 [==============================] - 17s 169ms/step - det_loss: 0.6462 - cls_loss: 0.5243 - box_loss: 0.0024 - reg_l2_loss: 0.0644 - loss: 0.7106 - learning_rate: 0.0099 - gradient_norm: 3.0200
# Epoch 4/50
# 100/100 [==============================] - 17s 167ms/step - det_loss: 0.5627 - cls_loss: 0.4488 - box_loss: 0.0023 - reg_l2_loss: 0.0645 - loss: 0.6272 - learning_rate: 0.0099 - gradient_norm: 2.9673
# Epoch 5/50
# 100/100 [==============================] - 16s 158ms/step - det_loss: 0.4835 - cls_loss: 0.3905 - box_loss: 0.0019 - reg_l2_loss: 0.0647 - loss: 0.5481 - learning_rate: 0.0098 - gradient_norm: 2.8831
# Epoch 6/50
# 100/100 [==============================] - 16s 162ms/step - det_loss: 0.4435 - cls_loss: 0.3602 - box_loss: 0.0017 - reg_l2_loss: 0.0648 - loss: 0.5082 - learning_rate: 0.0097 - gradient_norm: 2.8312
# Epoch 7/50
# 100/100 [==============================] - 16s 158ms/step - det_loss: 0.4307 - cls_loss: 0.3483 - box_loss: 0.0016 - reg_l2_loss: 0.0649 - loss: 0.4956 - learning_rate: 0.0096 - gradient_norm: 3.0061
# Epoch 8/50
# 100/100 [==============================] - 16s 158ms/step - det_loss: 0.3972 - cls_loss: 0.3254 - box_loss: 0.0014 - reg_l2_loss: 0.0650 - loss: 0.4622 - learning_rate: 0.0094 - gradient_norm: 2.9330
# Epoch 9/50
# 100/100 [==============================] - 16s 156ms/step - det_loss: 0.3866 - cls_loss: 0.3182 - box_loss: 0.0014 - reg_l2_loss: 0.0651 - loss: 0.4517 - learning_rate: 0.0093 - gradient_norm: 2.9970
# Epoch 10/50
# 100/100 [==============================] - 16s 158ms/step - det_loss: 0.3650 - cls_loss: 0.2946 - box_loss: 0.0014 - reg_l2_loss: 0.0652 - loss: 0.4303 - learning_rate: 0.0091 - gradient_norm: 2.9374
# Epoch 11/50
# 100/100 [==============================] - 16s 157ms/step - det_loss: 0.3322 - cls_loss: 0.2702 - box_loss: 0.0012 - reg_l2_loss: 0.0654 - loss: 0.3976 - learning_rate: 0.0089 - gradient_norm: 2.8633
# Epoch 12/50
# 100/100 [==============================] - 16s 157ms/step - det_loss: 0.3196 - cls_loss: 0.2620 - box_loss: 0.0012 - reg_l2_loss: 0.0654 - loss: 0.3851 - learning_rate: 0.0087 - gradient_norm: 2.6240
# Epoch 13/50
# 100/100 [==============================] - 17s 165ms/step - det_loss: 0.3088 - cls_loss: 0.2566 - box_loss: 0.0010 - reg_l2_loss: 0.0655 - loss: 0.3743 - learning_rate: 0.0085 - gradient_norm: 2.4993
# Epoch 14/50
# 100/100 [==============================] - 16s 157ms/step - det_loss: 0.3005 - cls_loss: 0.2437 - box_loss: 0.0011 - reg_l2_loss: 0.0656 - loss: 0.3660 - learning_rate: 0.0082 - gradient_norm: 2.5665
# Epoch 15/50
# 100/100 [==============================] - 16s 156ms/step - det_loss: 0.2988 - cls_loss: 0.2431 - box_loss: 0.0011 - reg_l2_loss: 0.0656 - loss: 0.3644 - learning_rate: 0.0080 - gradient_norm: 2.8348
# Epoch 16/50
# 100/100 [==============================] - 19s 189ms/step - det_loss: 0.2853 - cls_loss: 0.2361 - box_loss: 9.8315e-04 - reg_l2_loss: 0.0657 - loss: 0.3510 - learning_rate: 0.0077 - gradient_norm: 2.6282
# Epoch 17/50
# 100/100 [==============================] - 18s 177ms/step - det_loss: 0.2724 - cls_loss: 0.2249 - box_loss: 9.4923e-04 - reg_l2_loss: 0.0657 - loss: 0.3381 - learning_rate: 0.0075 - gradient_norm: 2.6763
# Epoch 18/50
# 100/100 [==============================] - 17s 168ms/step - det_loss: 0.2824 - cls_loss: 0.2307 - box_loss: 0.0010 - reg_l2_loss: 0.0658 - loss: 0.3481 - learning_rate: 0.0072 - gradient_norm: 2.8485
# Epoch 19/50
# 100/100 [==============================] - 15s 151ms/step - det_loss: 0.2668 - cls_loss: 0.2217 - box_loss: 9.0114e-04 - reg_l2_loss: 0.0659 - loss: 0.3326 - learning_rate: 0.0069 - gradient_norm: 2.7699
# Epoch 20/50
# 100/100 [==============================] - 14s 144ms/step - det_loss: 0.2533 - cls_loss: 0.2089 - box_loss: 8.8738e-04 - reg_l2_loss: 0.0659 - loss: 0.3192 - learning_rate: 0.0066 - gradient_norm: 2.6710
# Epoch 21/50
# 100/100 [==============================] - 14s 143ms/step - det_loss: 0.2481 - cls_loss: 0.2049 - box_loss: 8.6404e-04 - reg_l2_loss: 0.0659 - loss: 0.3140 - learning_rate: 0.0063 - gradient_norm: 2.4967
# Epoch 22/50
# 100/100 [==============================] - 15s 149ms/step - det_loss: 0.2367 - cls_loss: 0.1948 - box_loss: 8.3912e-04 - reg_l2_loss: 0.0660 - loss: 0.3027 - learning_rate: 0.0060 - gradient_norm: 2.4188
# Epoch 23/50
# 100/100 [==============================] - 14s 143ms/step - det_loss: 0.2457 - cls_loss: 0.2033 - box_loss: 8.4793e-04 - reg_l2_loss: 0.0660 - loss: 0.3116 - learning_rate: 0.0056 - gradient_norm: 2.7390
# Epoch 24/50
# 100/100 [==============================] - 16s 155ms/step - det_loss: 0.2291 - cls_loss: 0.1879 - box_loss: 8.2261e-04 - reg_l2_loss: 0.0660 - loss: 0.2951 - learning_rate: 0.0053 - gradient_norm: 2.5812
# Epoch 25/50
# 100/100 [==============================] - 16s 156ms/step - det_loss: 0.2293 - cls_loss: 0.1895 - box_loss: 7.9661e-04 - reg_l2_loss: 0.0660 - loss: 0.2954 - learning_rate: 0.0050 - gradient_norm: 2.3651
# Epoch 26/50
# 100/100 [==============================] - 18s 175ms/step - det_loss: 0.2015 - cls_loss: 0.1676 - box_loss: 6.7878e-04 - reg_l2_loss: 0.0660 - loss: 0.2675 - learning_rate: 0.0047 - gradient_norm: 2.2068
# Epoch 27/50
# 100/100 [==============================] - 17s 165ms/step - det_loss: 0.1912 - cls_loss: 0.1607 - box_loss: 6.0814e-04 - reg_l2_loss: 0.0660 - loss: 0.2572 - learning_rate: 0.0044 - gradient_norm: 2.2090
# Epoch 28/50
# 100/100 [==============================] - 16s 162ms/step - det_loss: 0.2063 - cls_loss: 0.1724 - box_loss: 6.7760e-04 - reg_l2_loss: 0.0660 - loss: 0.2724 - learning_rate: 0.0040 - gradient_norm: 2.3238
# Epoch 29/50
# 100/100 [==============================] - 18s 178ms/step - det_loss: 0.2058 - cls_loss: 0.1711 - box_loss: 6.9284e-04 - reg_l2_loss: 0.0661 - loss: 0.2718 - learning_rate: 0.0037 - gradient_norm: 2.3930
# Epoch 30/50
# 100/100 [==============================] - 17s 172ms/step - det_loss: 0.1969 - cls_loss: 0.1656 - box_loss: 6.2785e-04 - reg_l2_loss: 0.0661 - loss: 0.2630 - learning_rate: 0.0034 - gradient_norm: 2.1992
# Epoch 31/50
# 100/100 [==============================] - 21s 204ms/step - det_loss: 0.1956 - cls_loss: 0.1624 - box_loss: 6.6502e-04 - reg_l2_loss: 0.0661 - loss: 0.2617 - learning_rate: 0.0031 - gradient_norm: 2.2990
# Epoch 32/50
# 100/100 [==============================] - 17s 172ms/step - det_loss: 0.1877 - cls_loss: 0.1539 - box_loss: 6.7720e-04 - reg_l2_loss: 0.0661 - loss: 0.2538 - learning_rate: 0.0028 - gradient_norm: 2.2174
# Epoch 33/50
# 100/100 [==============================] - 14s 139ms/step - det_loss: 0.1915 - cls_loss: 0.1613 - box_loss: 6.0504e-04 - reg_l2_loss: 0.0661 - loss: 0.2576 - learning_rate: 0.0025 - gradient_norm: 2.2147
# Epoch 34/50
# 100/100 [==============================] - 15s 150ms/step - det_loss: 0.1799 - cls_loss: 0.1499 - box_loss: 6.0000e-04 - reg_l2_loss: 0.0660 - loss: 0.2459 - learning_rate: 0.0023 - gradient_norm: 2.0103
# Epoch 35/50
# 100/100 [==============================] - 15s 151ms/step - det_loss: 0.1863 - cls_loss: 0.1543 - box_loss: 6.3879e-04 - reg_l2_loss: 0.0660 - loss: 0.2523 - learning_rate: 0.0020 - gradient_norm: 2.2980
# Epoch 36/50
# 100/100 [==============================] - 14s 144ms/step - det_loss: 0.1760 - cls_loss: 0.1475 - box_loss: 5.7010e-04 - reg_l2_loss: 0.0660 - loss: 0.2421 - learning_rate: 0.0018 - gradient_norm: 2.0408
# Epoch 37/50
# 100/100 [==============================] - 14s 144ms/step - det_loss: 0.1744 - cls_loss: 0.1465 - box_loss: 5.5966e-04 - reg_l2_loss: 0.0660 - loss: 0.2405 - learning_rate: 0.0015 - gradient_norm: 2.1950
# Epoch 38/50
# 100/100 [==============================] - 18s 178ms/step - det_loss: 0.1706 - cls_loss: 0.1432 - box_loss: 5.4796e-04 - reg_l2_loss: 0.0660 - loss: 0.2367 - learning_rate: 0.0013 - gradient_norm: 2.1387
# Epoch 39/50
# 100/100 [==============================] - 18s 176ms/step - det_loss: 0.1624 - cls_loss: 0.1364 - box_loss: 5.1931e-04 - reg_l2_loss: 0.0660 - loss: 0.2284 - learning_rate: 0.0011 - gradient_norm: 1.9439
# Epoch 40/50
# 100/100 [==============================] - 15s 149ms/step - det_loss: 0.1692 - cls_loss: 0.1426 - box_loss: 5.3186e-04 - reg_l2_loss: 0.0660 - loss: 0.2353 - learning_rate: 8.9987e-04 - gradient_norm: 2.0062
# Epoch 41/50
# 100/100 [==============================] - 15s 151ms/step - det_loss: 0.1601 - cls_loss: 0.1346 - box_loss: 5.0959e-04 - reg_l2_loss: 0.0660 - loss: 0.2261 - learning_rate: 7.2505e-04 - gradient_norm: 1.9478
# Epoch 42/50
# 100/100 [==============================] - 16s 160ms/step - det_loss: 0.1644 - cls_loss: 0.1383 - box_loss: 5.2100e-04 - reg_l2_loss: 0.0660 - loss: 0.2304 - learning_rate: 5.6779e-04 - gradient_norm: 2.0528
# Epoch 43/50
# 100/100 [==============================] - 16s 162ms/step - det_loss: 0.1608 - cls_loss: 0.1355 - box_loss: 5.0470e-04 - reg_l2_loss: 0.0660 - loss: 0.2268 - learning_rate: 4.2875e-04 - gradient_norm: 1.8968
# Epoch 44/50
# 100/100 [==============================] - 14s 142ms/step - det_loss: 0.1599 - cls_loss: 0.1356 - box_loss: 4.8648e-04 - reg_l2_loss: 0.0660 - loss: 0.2260 - learning_rate: 3.0849e-04 - gradient_norm: 1.9607
# Epoch 45/50
# 100/100 [==============================] - 15s 146ms/step - det_loss: 0.1585 - cls_loss: 0.1331 - box_loss: 5.0971e-04 - reg_l2_loss: 0.0660 - loss: 0.2246 - learning_rate: 2.0751e-04 - gradient_norm: 1.9010
# Epoch 46/50
# 100/100 [==============================] - 15s 147ms/step - det_loss: 0.1572 - cls_loss: 0.1315 - box_loss: 5.1460e-04 - reg_l2_loss: 0.0660 - loss: 0.2232 - learning_rate: 1.2622e-04 - gradient_norm: 1.8124
# Epoch 47/50
# 100/100 [==============================] - 15s 148ms/step - det_loss: 0.1641 - cls_loss: 0.1385 - box_loss: 5.1187e-04 - reg_l2_loss: 0.0660 - loss: 0.2301 - learning_rate: 6.4957e-05 - gradient_norm: 1.9774
# Epoch 48/50
# 100/100 [==============================] - 15s 150ms/step - det_loss: 0.1580 - cls_loss: 0.1335 - box_loss: 4.8956e-04 - reg_l2_loss: 0.0660 - loss: 0.2240 - learning_rate: 2.3976e-05 - gradient_norm: 1.8560
# Epoch 49/50
# 100/100 [==============================] - 15s 147ms/step - det_loss: 0.1620 - cls_loss: 0.1366 - box_loss: 5.0649e-04 - reg_l2_loss: 0.0660 - loss: 0.2280 - learning_rate: 3.4419e-06 - gradient_norm: 1.9666
# Epoch 50/50
# 100/100 [==============================] - 16s 157ms/step - det_loss: 0.1632 - cls_loss: 0.1377 - box_loss: 5.1146e-04 - reg_l2_loss: 0.0660 - loss: 0.2293 - learning_rate: 3.4399e-06 - gradient_norm: 1.8026

# %%
lite1 = object_detector.create(train_data, model_spec=spec_lite1, batch_size=8, train_whole_model=True)
# Out:
# Epoch 1/50
# 100/100 [==============================] - 61s 428ms/step - det_loss: 1.4842 - cls_loss: 1.1035 - box_loss: 0.0076 - reg_l2_loss: 0.0716 - loss: 1.5558 - learning_rate: 0.0090 - gradient_norm: 2.3150
# Epoch 2/50
# 100/100 [==============================] - 25s 252ms/step - det_loss: 0.8441 - cls_loss: 0.6830 - box_loss: 0.0032 - reg_l2_loss: 0.0718 - loss: 0.9159 - learning_rate: 0.0100 - gradient_norm: 3.7531
# Epoch 3/50
# 100/100 [==============================] - 23s 227ms/step - det_loss: 0.6216 - cls_loss: 0.4999 - box_loss: 0.0024 - reg_l2_loss: 0.0721 - loss: 0.6937 - learning_rate: 0.0099 - gradient_norm: 3.3124
# Epoch 4/50
# 100/100 [==============================] - 32s 322ms/step - det_loss: 0.5031 - cls_loss: 0.4116 - box_loss: 0.0018 - reg_l2_loss: 0.0723 - loss: 0.5753 - learning_rate: 0.0099 - gradient_norm: 3.0033
# Epoch 5/50
# 100/100 [==============================] - 29s 285ms/step - det_loss: 0.4569 - cls_loss: 0.3744 - box_loss: 0.0017 - reg_l2_loss: 0.0724 - loss: 0.5293 - learning_rate: 0.0098 - gradient_norm: 3.1435
# Epoch 6/50
# 100/100 [==============================] - 23s 228ms/step - det_loss: 0.4150 - cls_loss: 0.3408 - box_loss: 0.0015 - reg_l2_loss: 0.0726 - loss: 0.4876 - learning_rate: 0.0097 - gradient_norm: 3.0490
# Epoch 7/50
# 100/100 [==============================] - 23s 232ms/step - det_loss: 0.3953 - cls_loss: 0.3243 - box_loss: 0.0014 - reg_l2_loss: 0.0727 - loss: 0.4680 - learning_rate: 0.0096 - gradient_norm: 3.2391
# Epoch 8/50
# 100/100 [==============================] - 23s 234ms/step - det_loss: 0.3649 - cls_loss: 0.3000 - box_loss: 0.0013 - reg_l2_loss: 0.0729 - loss: 0.4377 - learning_rate: 0.0094 - gradient_norm: 3.0496
# Epoch 9/50
# 100/100 [==============================] - 29s 293ms/step - det_loss: 0.3390 - cls_loss: 0.2800 - box_loss: 0.0012 - reg_l2_loss: 0.0730 - loss: 0.4120 - learning_rate: 0.0093 - gradient_norm: 3.0329
# Epoch 10/50
# 100/100 [==============================] - 27s 267ms/step - det_loss: 0.3274 - cls_loss: 0.2700 - box_loss: 0.0011 - reg_l2_loss: 0.0731 - loss: 0.4004 - learning_rate: 0.0091 - gradient_norm: 2.8218
# Epoch 11/50
# 100/100 [==============================] - 39s 393ms/step - det_loss: 0.3145 - cls_loss: 0.2612 - box_loss: 0.0011 - reg_l2_loss: 0.0732 - loss: 0.3877 - learning_rate: 0.0089 - gradient_norm: 2.9850
# Epoch 12/50
# 100/100 [==============================] - 36s 362ms/step - det_loss: 0.3104 - cls_loss: 0.2551 - box_loss: 0.0011 - reg_l2_loss: 0.0733 - loss: 0.3837 - learning_rate: 0.0087 - gradient_norm: 3.0635
# Epoch 13/50
# 100/100 [==============================] - 35s 353ms/step - det_loss: 0.2933 - cls_loss: 0.2411 - box_loss: 0.0010 - reg_l2_loss: 0.0734 - loss: 0.3667 - learning_rate: 0.0085 - gradient_norm: 2.8095
# Epoch 14/50
# 100/100 [==============================] - 34s 341ms/step - det_loss: 0.2727 - cls_loss: 0.2308 - box_loss: 8.3850e-04 - reg_l2_loss: 0.0735 - loss: 0.3462 - learning_rate: 0.0082 - gradient_norm: 2.6580
# Epoch 15/50
# 100/100 [==============================] - 34s 339ms/step - det_loss: 0.2567 - cls_loss: 0.2117 - box_loss: 8.9945e-04 - reg_l2_loss: 0.0735 - loss: 0.3302 - learning_rate: 0.0080 - gradient_norm: 2.7145
# Epoch 16/50
# 100/100 [==============================] - 38s 381ms/step - det_loss: 0.2666 - cls_loss: 0.2192 - box_loss: 9.4836e-04 - reg_l2_loss: 0.0736 - loss: 0.3402 - learning_rate: 0.0077 - gradient_norm: 2.8489
# Epoch 17/50
# 100/100 [==============================] - 34s 343ms/step - det_loss: 0.2392 - cls_loss: 0.1963 - box_loss: 8.5814e-04 - reg_l2_loss: 0.0737 - loss: 0.3129 - learning_rate: 0.0075 - gradient_norm: 2.7357
# Epoch 18/50
# 100/100 [==============================] - 34s 345ms/step - det_loss: 0.2400 - cls_loss: 0.1979 - box_loss: 8.4359e-04 - reg_l2_loss: 0.0737 - loss: 0.3138 - learning_rate: 0.0072 - gradient_norm: 2.6614
# Epoch 19/50
# 100/100 [==============================] - 34s 342ms/step - det_loss: 0.2414 - cls_loss: 0.2005 - box_loss: 8.1874e-04 - reg_l2_loss: 0.0738 - loss: 0.3152 - learning_rate: 0.0069 - gradient_norm: 2.6793
# Epoch 20/50
# 100/100 [==============================] - 34s 345ms/step - det_loss: 0.2234 - cls_loss: 0.1847 - box_loss: 7.7484e-04 - reg_l2_loss: 0.0738 - loss: 0.2972 - learning_rate: 0.0066 - gradient_norm: 2.4593
# Epoch 21/50
# 100/100 [==============================] - 36s 362ms/step - det_loss: 0.2282 - cls_loss: 0.1888 - box_loss: 7.8638e-04 - reg_l2_loss: 0.0738 - loss: 0.3020 - learning_rate: 0.0063 - gradient_norm: 2.6296
# Epoch 22/50
# 100/100 [==============================] - 33s 324ms/step - det_loss: 0.2113 - cls_loss: 0.1740 - box_loss: 7.4672e-04 - reg_l2_loss: 0.0739 - loss: 0.2852 - learning_rate: 0.0060 - gradient_norm: 2.5244
# Epoch 23/50
# 100/100 [==============================] - 32s 318ms/step - det_loss: 0.2104 - cls_loss: 0.1738 - box_loss: 7.3095e-04 - reg_l2_loss: 0.0739 - loss: 0.2843 - learning_rate: 0.0056 - gradient_norm: 2.7907
# Epoch 24/50
# 100/100 [==============================] - 33s 333ms/step - det_loss: 0.2035 - cls_loss: 0.1698 - box_loss: 6.7375e-04 - reg_l2_loss: 0.0739 - loss: 0.2774 - learning_rate: 0.0053 - gradient_norm: 2.2111
# Epoch 25/50
# 100/100 [==============================] - 36s 365ms/step - det_loss: 0.1952 - cls_loss: 0.1628 - box_loss: 6.4817e-04 - reg_l2_loss: 0.0739 - loss: 0.2691 - learning_rate: 0.0050 - gradient_norm: 2.4090
# Epoch 26/50
# 100/100 [==============================] - 37s 373ms/step - det_loss: 0.1850 - cls_loss: 0.1552 - box_loss: 5.9588e-04 - reg_l2_loss: 0.0739 - loss: 0.2590 - learning_rate: 0.0047 - gradient_norm: 2.4703
# Epoch 27/50
# 100/100 [==============================] - 35s 352ms/step - det_loss: 0.1980 - cls_loss: 0.1655 - box_loss: 6.4938e-04 - reg_l2_loss: 0.0740 - loss: 0.2719 - learning_rate: 0.0044 - gradient_norm: 2.6633
# Epoch 28/50
# 100/100 [==============================] - 34s 345ms/step - det_loss: 0.1781 - cls_loss: 0.1490 - box_loss: 5.8180e-04 - reg_l2_loss: 0.0740 - loss: 0.2521 - learning_rate: 0.0040 - gradient_norm: 2.4100
# Epoch 29/50
# 100/100 [==============================] - 35s 349ms/step - det_loss: 0.1758 - cls_loss: 0.1464 - box_loss: 5.8799e-04 - reg_l2_loss: 0.0740 - loss: 0.2498 - learning_rate: 0.0037 - gradient_norm: 2.4234
# Epoch 30/50
# 100/100 [==============================] - 34s 342ms/step - det_loss: 0.1710 - cls_loss: 0.1421 - box_loss: 5.7888e-04 - reg_l2_loss: 0.0740 - loss: 0.2450 - learning_rate: 0.0034 - gradient_norm: 2.0163
# Epoch 31/50
# 100/100 [==============================] - 37s 367ms/step - det_loss: 0.1620 - cls_loss: 0.1361 - box_loss: 5.1915e-04 - reg_l2_loss: 0.0740 - loss: 0.2360 - learning_rate: 0.0031 - gradient_norm: 2.0024
# Epoch 32/50
# 100/100 [==============================] - 35s 346ms/step - det_loss: 0.1666 - cls_loss: 0.1385 - box_loss: 5.6223e-04 - reg_l2_loss: 0.0740 - loss: 0.2406 - learning_rate: 0.0028 - gradient_norm: 2.1463
# Epoch 33/50
# 100/100 [==============================] - 35s 351ms/step - det_loss: 0.1620 - cls_loss: 0.1365 - box_loss: 5.1021e-04 - reg_l2_loss: 0.0740 - loss: 0.2360 - learning_rate: 0.0025 - gradient_norm: 2.1480
# Epoch 34/50
# 100/100 [==============================] - 38s 383ms/step - det_loss: 0.1592 - cls_loss: 0.1333 - box_loss: 5.1901e-04 - reg_l2_loss: 0.0740 - loss: 0.2332 - learning_rate: 0.0023 - gradient_norm: 2.2022
# Epoch 35/50
# 100/100 [==============================] - 40s 399ms/step - det_loss: 0.1574 - cls_loss: 0.1312 - box_loss: 5.2284e-04 - reg_l2_loss: 0.0740 - loss: 0.2313 - learning_rate: 0.0020 - gradient_norm: 2.1384
# Epoch 36/50
# 100/100 [==============================] - 36s 355ms/step - det_loss: 0.1653 - cls_loss: 0.1378 - box_loss: 5.4946e-04 - reg_l2_loss: 0.0740 - loss: 0.2393 - learning_rate: 0.0018 - gradient_norm: 2.0131
# Epoch 37/50
# 100/100 [==============================] - 35s 349ms/step - det_loss: 0.1582 - cls_loss: 0.1317 - box_loss: 5.2883e-04 - reg_l2_loss: 0.0739 - loss: 0.2321 - learning_rate: 0.0015 - gradient_norm: 2.1389
# Epoch 38/50
# 100/100 [==============================] - 34s 344ms/step - det_loss: 0.1480 - cls_loss: 0.1238 - box_loss: 4.8267e-04 - reg_l2_loss: 0.0739 - loss: 0.2219 - learning_rate: 0.0013 - gradient_norm: 2.0618
# Epoch 39/50
# 100/100 [==============================] - 35s 354ms/step - det_loss: 0.1465 - cls_loss: 0.1216 - box_loss: 4.9702e-04 - reg_l2_loss: 0.0739 - loss: 0.2204 - learning_rate: 0.0011 - gradient_norm: 1.7850
# Epoch 40/50
# 100/100 [==============================] - 34s 342ms/step - det_loss: 0.1472 - cls_loss: 0.1230 - box_loss: 4.8483e-04 - reg_l2_loss: 0.0739 - loss: 0.2212 - learning_rate: 8.9987e-04 - gradient_norm: 1.7809
# Epoch 41/50
# 100/100 [==============================] - 24s 235ms/step - det_loss: 0.1368 - cls_loss: 0.1157 - box_loss: 4.2137e-04 - reg_l2_loss: 0.0739 - loss: 0.2108 - learning_rate: 7.2505e-04 - gradient_norm: 1.8521
# Epoch 42/50
# 100/100 [==============================] - 26s 260ms/step - det_loss: 0.1389 - cls_loss: 0.1168 - box_loss: 4.4199e-04 - reg_l2_loss: 0.0739 - loss: 0.2129 - learning_rate: 5.6779e-04 - gradient_norm: 1.6755
# Epoch 43/50
# 100/100 [==============================] - 34s 337ms/step - det_loss: 0.1430 - cls_loss: 0.1204 - box_loss: 4.5170e-04 - reg_l2_loss: 0.0739 - loss: 0.2170 - learning_rate: 4.2875e-04 - gradient_norm: 1.9822
# Epoch 44/50
# 100/100 [==============================] - 37s 374ms/step - det_loss: 0.1378 - cls_loss: 0.1164 - box_loss: 4.2789e-04 - reg_l2_loss: 0.0739 - loss: 0.2117 - learning_rate: 3.0849e-04 - gradient_norm: 1.9027
# Epoch 45/50
# 100/100 [==============================] - 41s 409ms/step - det_loss: 0.1394 - cls_loss: 0.1168 - box_loss: 4.5191e-04 - reg_l2_loss: 0.0739 - loss: 0.2133 - learning_rate: 2.0751e-04 - gradient_norm: 1.8449
# Epoch 46/50
# 100/100 [==============================] - 34s 343ms/step - det_loss: 0.1354 - cls_loss: 0.1153 - box_loss: 4.0258e-04 - reg_l2_loss: 0.0739 - loss: 0.2093 - learning_rate: 1.2622e-04 - gradient_norm: 1.8412
# Epoch 47/50
# 100/100 [==============================] - 36s 359ms/step - det_loss: 0.1413 - cls_loss: 0.1180 - box_loss: 4.6468e-04 - reg_l2_loss: 0.0739 - loss: 0.2152 - learning_rate: 6.4957e-05 - gradient_norm: 1.9373
# Epoch 48/50
# 100/100 [==============================] - 33s 329ms/step - det_loss: 0.1390 - cls_loss: 0.1154 - box_loss: 4.7212e-04 - reg_l2_loss: 0.0739 - loss: 0.2129 - learning_rate: 2.3976e-05 - gradient_norm: 1.8498
# Epoch 49/50
# 100/100 [==============================] - 32s 318ms/step - det_loss: 0.1484 - cls_loss: 0.1248 - box_loss: 4.7080e-04 - reg_l2_loss: 0.0739 - loss: 0.2223 - learning_rate: 3.4419e-06 - gradient_norm: 1.8107
# Epoch 50/50
# 100/100 [==============================] - 23s 229ms/step - det_loss: 0.1470 - cls_loss: 0.1252 - box_loss: 4.3591e-04 - reg_l2_loss: 0.0739 - loss: 0.2209 - learning_rate: 3.4399e-06 - gradient_norm: 1.9781

# %%
lite2 = object_detector.create(train_data, model_spec=spec_lite2, batch_size=8, train_whole_model=True)

# %%
lite3 = object_detector.create(train_data, model_spec=spec_lite3, batch_size=8, train_whole_model=True)
# Out:
# Epoch 1/50
# 100/100 [==============================] - 63s 421ms/step - det_loss: 1.4112 - cls_loss: 1.0654 - box_loss: 0.0069 - reg_l2_loss: 0.0937 - loss: 1.5049 - learning_rate: 0.0090 - gradient_norm: 3.3098
# Epoch 2/50
# 100/100 [==============================] - 42s 422ms/step - det_loss: 0.7228 - cls_loss: 0.6066 - box_loss: 0.0023 - reg_l2_loss: 0.0939 - loss: 0.8167 - learning_rate: 0.0100 - gradient_norm: 3.8450
# Epoch 3/50
# 100/100 [==============================] - 42s 424ms/step - det_loss: 0.5296 - cls_loss: 0.4452 - box_loss: 0.0017 - reg_l2_loss: 0.0942 - loss: 0.6238 - learning_rate: 0.0099 - gradient_norm: 3.6698
# Epoch 4/50
# 100/100 [==============================] - 43s 427ms/step - det_loss: 0.4426 - cls_loss: 0.3757 - box_loss: 0.0013 - reg_l2_loss: 0.0945 - loss: 0.5371 - learning_rate: 0.0099 - gradient_norm: 3.3005
# Epoch 5/50
# 100/100 [==============================] - 40s 402ms/step - det_loss: 0.4011 - cls_loss: 0.3395 - box_loss: 0.0012 - reg_l2_loss: 0.0946 - loss: 0.4957 - learning_rate: 0.0098 - gradient_norm: 3.0698
# Epoch 6/50
# 100/100 [==============================] - 41s 411ms/step - det_loss: 0.3783 - cls_loss: 0.3214 - box_loss: 0.0011 - reg_l2_loss: 0.0947 - loss: 0.4730 - learning_rate: 0.0097 - gradient_norm: 3.0662
# Epoch 7/50
# 100/100 [==============================] - 40s 400ms/step - det_loss: 0.3452 - cls_loss: 0.2958 - box_loss: 9.8670e-04 - reg_l2_loss: 0.0949 - loss: 0.4400 - learning_rate: 0.0096 - gradient_norm: 3.1367
# Epoch 8/50
# 100/100 [==============================] - 40s 403ms/step - det_loss: 0.3255 - cls_loss: 0.2743 - box_loss: 0.0010 - reg_l2_loss: 0.0950 - loss: 0.4205 - learning_rate: 0.0094 - gradient_norm: 3.1332
# Epoch 9/50
# 100/100 [==============================] - 40s 404ms/step - det_loss: 0.3130 - cls_loss: 0.2640 - box_loss: 9.7941e-04 - reg_l2_loss: 0.0951 - loss: 0.4081 - learning_rate: 0.0093 - gradient_norm: 2.9591
# Epoch 10/50
# 100/100 [==============================] - 41s 406ms/step - det_loss: 0.2890 - cls_loss: 0.2467 - box_loss: 8.4598e-04 - reg_l2_loss: 0.0952 - loss: 0.3842 - learning_rate: 0.0091 - gradient_norm: 2.7170
# Epoch 11/50
# 100/100 [==============================] - 40s 404ms/step - det_loss: 0.2664 - cls_loss: 0.2288 - box_loss: 7.5143e-04 - reg_l2_loss: 0.0953 - loss: 0.3617 - learning_rate: 0.0089 - gradient_norm: 2.6956
# Epoch 12/50
# 100/100 [==============================] - 40s 401ms/step - det_loss: 0.2582 - cls_loss: 0.2227 - box_loss: 7.0958e-04 - reg_l2_loss: 0.0954 - loss: 0.3535 - learning_rate: 0.0087 - gradient_norm: 2.8326
# Epoch 13/50
# 100/100 [==============================] - 40s 401ms/step - det_loss: 0.2682 - cls_loss: 0.2301 - box_loss: 7.6253e-04 - reg_l2_loss: 0.0954 - loss: 0.3636 - learning_rate: 0.0085 - gradient_norm: 3.0342
# Epoch 14/50
# 100/100 [==============================] - 40s 399ms/step - det_loss: 0.2500 - cls_loss: 0.2094 - box_loss: 8.1241e-04 - reg_l2_loss: 0.0955 - loss: 0.3455 - learning_rate: 0.0082 - gradient_norm: 2.6021
# Epoch 15/50
# 100/100 [==============================] - 41s 410ms/step - det_loss: 0.2372 - cls_loss: 0.1992 - box_loss: 7.5930e-04 - reg_l2_loss: 0.0956 - loss: 0.3328 - learning_rate: 0.0080 - gradient_norm: 2.8563
# Epoch 16/50
# 100/100 [==============================] - 40s 400ms/step - det_loss: 0.2467 - cls_loss: 0.2095 - box_loss: 7.4422e-04 - reg_l2_loss: 0.0956 - loss: 0.3424 - learning_rate: 0.0077 - gradient_norm: 3.1557
# Epoch 17/50
# 100/100 [==============================] - 40s 402ms/step - det_loss: 0.2345 - cls_loss: 0.2002 - box_loss: 6.8648e-04 - reg_l2_loss: 0.0957 - loss: 0.3302 - learning_rate: 0.0075 - gradient_norm: 3.0116
# Epoch 18/50
# 100/100 [==============================] - 40s 402ms/step - det_loss: 0.2277 - cls_loss: 0.1939 - box_loss: 6.7651e-04 - reg_l2_loss: 0.0958 - loss: 0.3235 - learning_rate: 0.0072 - gradient_norm: 2.7656
# Epoch 19/50
# 100/100 [==============================] - 40s 403ms/step - det_loss: 0.2151 - cls_loss: 0.1839 - box_loss: 6.2414e-04 - reg_l2_loss: 0.0958 - loss: 0.3109 - learning_rate: 0.0069 - gradient_norm: 2.5027
# Epoch 20/50
# 100/100 [==============================] - 40s 398ms/step - det_loss: 0.2019 - cls_loss: 0.1718 - box_loss: 6.0190e-04 - reg_l2_loss: 0.0958 - loss: 0.2977 - learning_rate: 0.0066 - gradient_norm: 2.5017
# Epoch 21/50
# 100/100 [==============================] - 46s 460ms/step - det_loss: 0.2000 - cls_loss: 0.1720 - box_loss: 5.5935e-04 - reg_l2_loss: 0.0959 - loss: 0.2958 - learning_rate: 0.0063 - gradient_norm: 2.5034
# Epoch 22/50
# 100/100 [==============================] - 53s 529ms/step - det_loss: 0.1804 - cls_loss: 0.1512 - box_loss: 5.8256e-04 - reg_l2_loss: 0.0959 - loss: 0.2762 - learning_rate: 0.0060 - gradient_norm: 2.3383
# Epoch 23/50
# 100/100 [==============================] - 82s 820ms/step - det_loss: 0.1789 - cls_loss: 0.1532 - box_loss: 5.1463e-04 - reg_l2_loss: 0.0959 - loss: 0.2748 - learning_rate: 0.0056 - gradient_norm: 2.3204
# Epoch 24/50
# 100/100 [==============================] - 74s 739ms/step - det_loss: 0.1712 - cls_loss: 0.1438 - box_loss: 5.4700e-04 - reg_l2_loss: 0.0959 - loss: 0.2671 - learning_rate: 0.0053 - gradient_norm: 2.3604
# Epoch 25/50
# 100/100 [==============================] - 81s 814ms/step - det_loss: 0.1581 - cls_loss: 0.1344 - box_loss: 4.7461e-04 - reg_l2_loss: 0.0959 - loss: 0.2540 - learning_rate: 0.0050 - gradient_norm: 1.9712
# Epoch 26/50
# 100/100 [==============================] - 76s 758ms/step - det_loss: 0.1727 - cls_loss: 0.1481 - box_loss: 4.9318e-04 - reg_l2_loss: 0.0959 - loss: 0.2686 - learning_rate: 0.0047 - gradient_norm: 2.5980
# Epoch 27/50
# 100/100 [==============================] - 76s 763ms/step - det_loss: 0.1578 - cls_loss: 0.1341 - box_loss: 4.7296e-04 - reg_l2_loss: 0.0959 - loss: 0.2537 - learning_rate: 0.0044 - gradient_norm: 2.2041
# Epoch 28/50
# 100/100 [==============================] - 72s 715ms/step - det_loss: 0.1517 - cls_loss: 0.1304 - box_loss: 4.2452e-04 - reg_l2_loss: 0.0959 - loss: 0.2476 - learning_rate: 0.0040 - gradient_norm: 2.2540
# Epoch 29/50
# 100/100 [==============================] - 55s 551ms/step - det_loss: 0.1538 - cls_loss: 0.1329 - box_loss: 4.1891e-04 - reg_l2_loss: 0.0959 - loss: 0.2497 - learning_rate: 0.0037 - gradient_norm: 2.3754
# Epoch 30/50
# 100/100 [==============================] - 64s 641ms/step - det_loss: 0.1495 - cls_loss: 0.1276 - box_loss: 4.3775e-04 - reg_l2_loss: 0.0959 - loss: 0.2454 - learning_rate: 0.0034 - gradient_norm: 2.1638
# Epoch 31/50
# 100/100 [==============================] - 80s 802ms/step - det_loss: 0.1412 - cls_loss: 0.1218 - box_loss: 3.8779e-04 - reg_l2_loss: 0.0959 - loss: 0.2371 - learning_rate: 0.0031 - gradient_norm: 2.2783
# Epoch 32/50
# 100/100 [==============================] - 75s 748ms/step - det_loss: 0.1572 - cls_loss: 0.1343 - box_loss: 4.5825e-04 - reg_l2_loss: 0.0959 - loss: 0.2531 - learning_rate: 0.0028 - gradient_norm: 2.3935
# Epoch 33/50
# 100/100 [==============================] - 62s 615ms/step - det_loss: 0.1313 - cls_loss: 0.1114 - box_loss: 3.9832e-04 - reg_l2_loss: 0.0959 - loss: 0.2271 - learning_rate: 0.0025 - gradient_norm: 1.9887
# Epoch 34/50
# 100/100 [==============================] - 41s 413ms/step - det_loss: 0.1326 - cls_loss: 0.1134 - box_loss: 3.8445e-04 - reg_l2_loss: 0.0959 - loss: 0.2285 - learning_rate: 0.0023 - gradient_norm: 1.8915
# Epoch 35/50
# 100/100 [==============================] - 44s 437ms/step - det_loss: 0.1237 - cls_loss: 0.1065 - box_loss: 3.4375e-04 - reg_l2_loss: 0.0959 - loss: 0.2196 - learning_rate: 0.0020 - gradient_norm: 1.9165
# Epoch 36/50
# 100/100 [==============================] - 43s 430ms/step - det_loss: 0.1224 - cls_loss: 0.1058 - box_loss: 3.3203e-04 - reg_l2_loss: 0.0958 - loss: 0.2183 - learning_rate: 0.0018 - gradient_norm: 1.8193
# Epoch 37/50
# 100/100 [==============================] - 50s 502ms/step - det_loss: 0.1269 - cls_loss: 0.1110 - box_loss: 3.1695e-04 - reg_l2_loss: 0.0958 - loss: 0.2227 - learning_rate: 0.0015 - gradient_norm: 1.8432
# Epoch 38/50
# 100/100 [==============================] - 74s 742ms/step - det_loss: 0.1202 - cls_loss: 0.1038 - box_loss: 3.2989e-04 - reg_l2_loss: 0.0958 - loss: 0.2161 - learning_rate: 0.0013 - gradient_norm: 1.7383
# Epoch 39/50
# 100/100 [==============================] - 66s 660ms/step - det_loss: 0.1219 - cls_loss: 0.1046 - box_loss: 3.4566e-04 - reg_l2_loss: 0.0958 - loss: 0.2177 - learning_rate: 0.0011 - gradient_norm: 1.7786
# Epoch 40/50
# 100/100 [==============================] - 99s 990ms/step - det_loss: 0.1185 - cls_loss: 0.1023 - box_loss: 3.2329e-04 - reg_l2_loss: 0.0958 - loss: 0.2143 - learning_rate: 8.9987e-04 - gradient_norm: 1.7409
# Epoch 41/50
# 100/100 [==============================] - 92s 917ms/step - det_loss: 0.1187 - cls_loss: 0.1027 - box_loss: 3.2070e-04 - reg_l2_loss: 0.0958 - loss: 0.2146 - learning_rate: 7.2505e-04 - gradient_norm: 1.7107
# Epoch 42/50
# 100/100 [==============================] - 86s 852ms/step - det_loss: 0.1159 - cls_loss: 0.0993 - box_loss: 3.3188e-04 - reg_l2_loss: 0.0958 - loss: 0.2117 - learning_rate: 5.6779e-04 - gradient_norm: 1.7260
# Epoch 43/50
# 100/100 [==============================] - 96s 964ms/step - det_loss: 0.1169 - cls_loss: 0.1010 - box_loss: 3.1787e-04 - reg_l2_loss: 0.0958 - loss: 0.2127 - learning_rate: 4.2875e-04 - gradient_norm: 1.6689
# Epoch 44/50
# 100/100 [==============================] - 86s 859ms/step - det_loss: 0.1284 - cls_loss: 0.1100 - box_loss: 3.6821e-04 - reg_l2_loss: 0.0958 - loss: 0.2242 - learning_rate: 3.0849e-04 - gradient_norm: 1.9595
# Epoch 45/50
# 100/100 [==============================] - 84s 845ms/step - det_loss: 0.1118 - cls_loss: 0.0968 - box_loss: 3.0031e-04 - reg_l2_loss: 0.0958 - loss: 0.2076 - learning_rate: 2.0751e-04 - gradient_norm: 1.6190
# Epoch 46/50
# 100/100 [==============================] - 84s 836ms/step - det_loss: 0.1165 - cls_loss: 0.1004 - box_loss: 3.2191e-04 - reg_l2_loss: 0.0958 - loss: 0.2123 - learning_rate: 1.2622e-04 - gradient_norm: 1.7561
# Epoch 47/50
# 100/100 [==============================] - 78s 782ms/step - det_loss: 0.1102 - cls_loss: 0.0955 - box_loss: 2.9463e-04 - reg_l2_loss: 0.0958 - loss: 0.2060 - learning_rate: 6.4957e-05 - gradient_norm: 1.5745
# Epoch 48/50
# 100/100 [==============================] - 73s 731ms/step - det_loss: 0.1172 - cls_loss: 0.1010 - box_loss: 3.2452e-04 - reg_l2_loss: 0.0958 - loss: 0.2130 - learning_rate: 2.3976e-05 - gradient_norm: 1.8469
# Epoch 49/50
# 100/100 [==============================] - 71s 712ms/step - det_loss: 0.1142 - cls_loss: 0.0986 - box_loss: 3.1242e-04 - reg_l2_loss: 0.0958 - loss: 0.2100 - learning_rate: 3.4419e-06 - gradient_norm: 1.7724
# Epoch 50/50
# 100/100 [==============================] - 80s 795ms/step - det_loss: 0.1120 - cls_loss: 0.0961 - box_loss: 3.1722e-04 - reg_l2_loss: 0.0958 - loss: 0.2078 - learning_rate: 3.4399e-06 - gradient_norm: 1.7182

# %%
try:
  lite4 = object_detector.create(train_data, model_spec=spec_lite4, batch_size=3, train_whole_model=True)
except:
  lite4 = object_detector.create(train_data, model_spec=spec_lite4, batch_size=2, train_whole_model=True)
# Out:
# Epoch 1/50
# 267/267 [==============================] - 133s 413ms/step - det_loss: 1.0672 - cls_loss: 0.8540 - box_loss: 0.0043 - reg_l2_loss: 0.1092 - loss: 1.1764 - learning_rate: 0.0059 - gradient_norm: 5.5858
# Epoch 2/50
# 267/267 [==============================] - 111s 415ms/step - det_loss: 0.5645 - cls_loss: 0.4771 - box_loss: 0.0017 - reg_l2_loss: 0.1096 - loss: 0.6740 - learning_rate: 0.0037 - gradient_norm: 4.9918
# Epoch 3/50
# 267/267 [==============================] - 112s 417ms/step - det_loss: 0.4747 - cls_loss: 0.4096 - box_loss: 0.0013 - reg_l2_loss: 0.1097 - loss: 0.5844 - learning_rate: 0.0037 - gradient_norm: 4.6012
# Epoch 4/50
# 267/267 [==============================] - 109s 409ms/step - det_loss: 0.4282 - cls_loss: 0.3681 - box_loss: 0.0012 - reg_l2_loss: 0.1098 - loss: 0.5380 - learning_rate: 0.0037 - gradient_norm: 4.8646
# Epoch 5/50
# 267/267 [==============================] - 130s 487ms/step - det_loss: 0.3787 - cls_loss: 0.3237 - box_loss: 0.0011 - reg_l2_loss: 0.1100 - loss: 0.4887 - learning_rate: 0.0037 - gradient_norm: 4.7732
# Epoch 6/50
# 267/267 [==============================] - 115s 429ms/step - det_loss: 0.3422 - cls_loss: 0.2928 - box_loss: 9.8699e-04 - reg_l2_loss: 0.1101 - loss: 0.4523 - learning_rate: 0.0036 - gradient_norm: 4.7251
# Epoch 7/50
# 267/267 [==============================] - 113s 423ms/step - det_loss: 0.3213 - cls_loss: 0.2775 - box_loss: 8.7661e-04 - reg_l2_loss: 0.1102 - loss: 0.4315 - learning_rate: 0.0036 - gradient_norm: 4.5461
# Epoch 8/50
# 267/267 [==============================] - 107s 400ms/step - det_loss: 0.3036 - cls_loss: 0.2609 - box_loss: 8.5422e-04 - reg_l2_loss: 0.1103 - loss: 0.4140 - learning_rate: 0.0035 - gradient_norm: 4.5555
# Epoch 9/50
# 267/267 [==============================] - 193s 724ms/step - det_loss: 0.2770 - cls_loss: 0.2355 - box_loss: 8.3077e-04 - reg_l2_loss: 0.1104 - loss: 0.3874 - learning_rate: 0.0035 - gradient_norm: 4.4572
# Epoch 10/50
# 267/267 [==============================] - 196s 735ms/step - det_loss: 0.2852 - cls_loss: 0.2426 - box_loss: 8.5209e-04 - reg_l2_loss: 0.1105 - loss: 0.3957 - learning_rate: 0.0034 - gradient_norm: 4.7860
# Epoch 11/50
# 267/267 [==============================] - 178s 665ms/step - det_loss: 0.2529 - cls_loss: 0.2157 - box_loss: 7.4281e-04 - reg_l2_loss: 0.1106 - loss: 0.3635 - learning_rate: 0.0033 - gradient_norm: 4.2520
# Epoch 12/50
# 267/267 [==============================] - 191s 717ms/step - det_loss: 0.2578 - cls_loss: 0.2213 - box_loss: 7.3028e-04 - reg_l2_loss: 0.1107 - loss: 0.3685 - learning_rate: 0.0033 - gradient_norm: 4.3684
# Epoch 13/50
# 267/267 [==============================] - 187s 700ms/step - det_loss: 0.2455 - cls_loss: 0.2101 - box_loss: 7.0916e-04 - reg_l2_loss: 0.1108 - loss: 0.3563 - learning_rate: 0.0032 - gradient_norm: 4.4806
# Epoch 14/50
# 267/267 [==============================] - 182s 679ms/step - det_loss: 0.2366 - cls_loss: 0.2011 - box_loss: 7.0914e-04 - reg_l2_loss: 0.1108 - loss: 0.3475 - learning_rate: 0.0031 - gradient_norm: 4.1489
# Epoch 15/50
# 267/267 [==============================] - 161s 603ms/step - det_loss: 0.2297 - cls_loss: 0.1971 - box_loss: 6.5251e-04 - reg_l2_loss: 0.1109 - loss: 0.3406 - learning_rate: 0.0030 - gradient_norm: 4.1013
# Epoch 16/50
# 267/267 [==============================] - 203s 760ms/step - det_loss: 0.2081 - cls_loss: 0.1779 - box_loss: 6.0343e-04 - reg_l2_loss: 0.1109 - loss: 0.3190 - learning_rate: 0.0029 - gradient_norm: 3.9639
# Epoch 17/50
# 267/267 [==============================] - 208s 777ms/step - det_loss: 0.2043 - cls_loss: 0.1734 - box_loss: 6.1861e-04 - reg_l2_loss: 0.1110 - loss: 0.3153 - learning_rate: 0.0028 - gradient_norm: 4.1800
# Epoch 18/50
# 267/267 [==============================] - 192s 720ms/step - det_loss: 0.2196 - cls_loss: 0.1881 - box_loss: 6.3057e-04 - reg_l2_loss: 0.1110 - loss: 0.3306 - learning_rate: 0.0027 - gradient_norm: 4.0410
# Epoch 19/50
# 267/267 [==============================] - 110s 410ms/step - det_loss: 0.1957 - cls_loss: 0.1653 - box_loss: 6.0626e-04 - reg_l2_loss: 0.1111 - loss: 0.3067 - learning_rate: 0.0026 - gradient_norm: 3.6650
# Epoch 20/50
# 267/267 [==============================] - 109s 408ms/step - det_loss: 0.1885 - cls_loss: 0.1636 - box_loss: 4.9695e-04 - reg_l2_loss: 0.1111 - loss: 0.2996 - learning_rate: 0.0025 - gradient_norm: 3.5905
# Epoch 21/50
# 267/267 [==============================] - 104s 389ms/step - det_loss: 0.1711 - cls_loss: 0.1469 - box_loss: 4.8433e-04 - reg_l2_loss: 0.1111 - loss: 0.2822 - learning_rate: 0.0024 - gradient_norm: 3.3412
# Epoch 22/50
# 267/267 [==============================] - 104s 389ms/step - det_loss: 0.1743 - cls_loss: 0.1514 - box_loss: 4.5771e-04 - reg_l2_loss: 0.1111 - loss: 0.2854 - learning_rate: 0.0022 - gradient_norm: 3.6116
# Epoch 23/50
# 267/267 [==============================] - 103s 386ms/step - det_loss: 0.1719 - cls_loss: 0.1486 - box_loss: 4.6652e-04 - reg_l2_loss: 0.1111 - loss: 0.2830 - learning_rate: 0.0021 - gradient_norm: 3.5878
# Epoch 24/50
# 267/267 [==============================] - 104s 391ms/step - det_loss: 0.1682 - cls_loss: 0.1424 - box_loss: 5.1666e-04 - reg_l2_loss: 0.1111 - loss: 0.2793 - learning_rate: 0.0020 - gradient_norm: 3.5313
# Epoch 25/50
# 267/267 [==============================] - 103s 386ms/step - det_loss: 0.1673 - cls_loss: 0.1420 - box_loss: 5.0468e-04 - reg_l2_loss: 0.1111 - loss: 0.2784 - learning_rate: 0.0019 - gradient_norm: 3.7064
# Epoch 26/50
# 267/267 [==============================] - 103s 387ms/step - det_loss: 0.1600 - cls_loss: 0.1351 - box_loss: 4.9839e-04 - reg_l2_loss: 0.1111 - loss: 0.2711 - learning_rate: 0.0018 - gradient_norm: 3.2734
# Epoch 27/50
# 267/267 [==============================] - 104s 388ms/step - det_loss: 0.1452 - cls_loss: 0.1248 - box_loss: 4.0851e-04 - reg_l2_loss: 0.1111 - loss: 0.2563 - learning_rate: 0.0016 - gradient_norm: 3.1972
# Epoch 28/50
# 267/267 [==============================] - 103s 387ms/step - det_loss: 0.1374 - cls_loss: 0.1185 - box_loss: 3.7818e-04 - reg_l2_loss: 0.1111 - loss: 0.2484 - learning_rate: 0.0015 - gradient_norm: 3.0174
# Epoch 29/50
# 267/267 [==============================] - 103s 387ms/step - det_loss: 0.1433 - cls_loss: 0.1238 - box_loss: 3.8940e-04 - reg_l2_loss: 0.1111 - loss: 0.2544 - learning_rate: 0.0014 - gradient_norm: 2.9922
# Epoch 30/50
# 267/267 [==============================] - 103s 387ms/step - det_loss: 0.1348 - cls_loss: 0.1159 - box_loss: 3.7724e-04 - reg_l2_loss: 0.1111 - loss: 0.2458 - learning_rate: 0.0013 - gradient_norm: 2.9924
# Epoch 31/50
# 267/267 [==============================] - 103s 385ms/step - det_loss: 0.1330 - cls_loss: 0.1150 - box_loss: 3.6105e-04 - reg_l2_loss: 0.1110 - loss: 0.2441 - learning_rate: 0.0012 - gradient_norm: 2.9811
# Epoch 32/50
# 267/267 [==============================] - 104s 388ms/step - det_loss: 0.1347 - cls_loss: 0.1146 - box_loss: 4.0119e-04 - reg_l2_loss: 0.1110 - loss: 0.2457 - learning_rate: 0.0011 - gradient_norm: 3.0760
# Epoch 33/50
# 267/267 [==============================] - 103s 387ms/step - det_loss: 0.1296 - cls_loss: 0.1119 - box_loss: 3.5400e-04 - reg_l2_loss: 0.1110 - loss: 0.2406 - learning_rate: 9.5506e-04 - gradient_norm: 2.9693
# Epoch 34/50
# 267/267 [==============================] - 104s 390ms/step - det_loss: 0.1263 - cls_loss: 0.1079 - box_loss: 3.6806e-04 - reg_l2_loss: 0.1110 - loss: 0.2373 - learning_rate: 8.5230e-04 - gradient_norm: 2.7997
# Epoch 35/50
# 267/267 [==============================] - 104s 388ms/step - det_loss: 0.1349 - cls_loss: 0.1171 - box_loss: 3.5610e-04 - reg_l2_loss: 0.1110 - loss: 0.2459 - learning_rate: 7.5374e-04 - gradient_norm: 2.9744
# Epoch 36/50
# 267/267 [==============================] - 106s 398ms/step - det_loss: 0.1137 - cls_loss: 0.0992 - box_loss: 2.8958e-04 - reg_l2_loss: 0.1110 - loss: 0.2247 - learning_rate: 6.5978e-04 - gradient_norm: 2.6696
# Epoch 37/50
# 267/267 [==============================] - 107s 401ms/step - det_loss: 0.1217 - cls_loss: 0.1059 - box_loss: 3.1713e-04 - reg_l2_loss: 0.1110 - loss: 0.2327 - learning_rate: 5.7082e-04 - gradient_norm: 2.8196
# Epoch 38/50
# 267/267 [==============================] - 151s 567ms/step - det_loss: 0.1276 - cls_loss: 0.1113 - box_loss: 3.2744e-04 - reg_l2_loss: 0.1110 - loss: 0.2386 - learning_rate: 4.8722e-04 - gradient_norm: 2.8620
# Epoch 39/50
# 267/267 [==============================] - 181s 678ms/step - det_loss: 0.1264 - cls_loss: 0.1101 - box_loss: 3.2657e-04 - reg_l2_loss: 0.1110 - loss: 0.2374 - learning_rate: 4.0932e-04 - gradient_norm: 2.8571
# Epoch 40/50
# 267/267 [==============================] - 180s 675ms/step - det_loss: 0.1125 - cls_loss: 0.0980 - box_loss: 2.9148e-04 - reg_l2_loss: 0.1110 - loss: 0.2235 - learning_rate: 3.3744e-04 - gradient_norm: 2.6232
# Epoch 41/50
# 267/267 [==============================] - 201s 754ms/step - det_loss: 0.1211 - cls_loss: 0.1049 - box_loss: 3.2337e-04 - reg_l2_loss: 0.1110 - loss: 0.2321 - learning_rate: 2.7188e-04 - gradient_norm: 2.6688
# Epoch 42/50
# 267/267 [==============================] - 205s 769ms/step - det_loss: 0.1118 - cls_loss: 0.0958 - box_loss: 3.1931e-04 - reg_l2_loss: 0.1109 - loss: 0.2227 - learning_rate: 2.1291e-04 - gradient_norm: 2.5672
# Epoch 43/50
# 267/267 [==============================] - 197s 740ms/step - det_loss: 0.1147 - cls_loss: 0.0994 - box_loss: 3.0697e-04 - reg_l2_loss: 0.1109 - loss: 0.2257 - learning_rate: 1.6077e-04 - gradient_norm: 2.6688
# Epoch 44/50
# 267/267 [==============================] - 196s 736ms/step - det_loss: 0.1152 - cls_loss: 0.0991 - box_loss: 3.2262e-04 - reg_l2_loss: 0.1109 - loss: 0.2261 - learning_rate: 1.1568e-04 - gradient_norm: 2.6615
# Epoch 45/50
# 267/267 [==============================] - 210s 787ms/step - det_loss: 0.1120 - cls_loss: 0.0960 - box_loss: 3.2032e-04 - reg_l2_loss: 0.1109 - loss: 0.2229 - learning_rate: 7.7808e-05 - gradient_norm: 2.6950
# Epoch 46/50
# 267/267 [==============================] - 171s 639ms/step - det_loss: 0.1152 - cls_loss: 0.0997 - box_loss: 3.1064e-04 - reg_l2_loss: 0.1109 - loss: 0.2262 - learning_rate: 4.7326e-05 - gradient_norm: 2.5549
# Epoch 47/50
# 267/267 [==============================] - 203s 761ms/step - det_loss: 0.1126 - cls_loss: 0.0985 - box_loss: 2.8198e-04 - reg_l2_loss: 0.1109 - loss: 0.2236 - learning_rate: 2.4354e-05 - gradient_norm: 2.5750
# Epoch 48/50
# 267/267 [==============================] - 198s 740ms/step - det_loss: 0.1073 - cls_loss: 0.0937 - box_loss: 2.7353e-04 - reg_l2_loss: 0.1109 - loss: 0.2183 - learning_rate: 8.9863e-06 - gradient_norm: 2.4199
# Epoch 49/50
# 267/267 [==============================] - 108s 406ms/step - det_loss: 0.1072 - cls_loss: 0.0935 - box_loss: 2.7548e-04 - reg_l2_loss: 0.1109 - loss: 0.2182 - learning_rate: 1.2867e-06 - gradient_norm: 2.3411
# Epoch 50/50
# 267/267 [==============================] - 154s 576ms/step - det_loss: 0.1169 - cls_loss: 0.1000 - box_loss: 3.3783e-04 - reg_l2_loss: 0.1109 - loss: 0.2278 - learning_rate: 1.2866e-06 - gradient_norm: 2.6300

# %% [markdown]
# **Step 4. Evaluate the model with the test data.**
#
# After training the object detection model using the images in the training dataset, use the remaining 25 images in the test dataset to evaluate how the model performs against new data it has never seen before.
#
# As the default batch size is 64, it will take 1 step to go through the 25 images in the test dataset.
#
# The evaluation metrics are same as [COCO](https://cocodataset.org/#detection-eval).

# %%
lite0_results = lite0.evaluate(test_data, batch_size=8)
lite0_results
# Out:
# 10/10 [==============================] - 5s 221ms/step
# {'AP': 0.8252863,
#  'AP50': 0.9416739,
#  'AP75': 0.914654,
#  'APs': -1.0,
#  'APm': -1.0,
#  'APl': 0.8253578,
#  'ARmax1': 0.82625,
#  'ARmax10': 0.885,
#  'ARmax100': 0.885,
#  'ARs': -1.0,
#  'ARm': -1.0,
#  'ARl': 0.885,
#  'AP_/option1': 0.7087984,
#  'AP_/option2': 0.85263634,
#  'AP_/option3': 0.9021645,
#  'AP_/option4': 0.7733878,
#  'AP_/punch': 0.89384556,
#  'AP_/thumb': 0.8190582,
#  'AP_/ok': 0.7526629,
#  'AP_/back': 0.89973706}

# %%
lite1_results = lite1.evaluate(test_data)
lite1_results
# Out:
# 2/2 [==============================] - 11s 3s/step
# {'AP': 0.8337193,
#  'AP50': 0.93858576,
#  'AP75': 0.9255801,
#  'APs': -1.0,
#  'APm': -1.0,
#  'APl': 0.8337506,
#  'ARmax1': 0.84125,
#  'ARmax10': 0.88,
#  'ARmax100': 0.88,
#  'ARs': -1.0,
#  'ARm': -1.0,
#  'ARl': 0.88,
#  'AP_/option1': 0.683847,
#  'AP_/option2': 0.88074094,
#  'AP_/option3': 0.90330034,
#  'AP_/option4': 0.71971965,
#  'AP_/punch': 0.8804275,
#  'AP_/thumb': 0.8806569,
#  'AP_/ok': 0.8031568,
#  'AP_/back': 0.9179054}

# %%
lite2_results = lite2.evaluate(test_data)
lite2_results
# Out:
# 2/2 [==============================] - 9s 2s/step
# {'AP': 0.8695503,
#  'AP50': 0.956028,
#  'AP75': 0.9529703,
#  'APs': -1.0,
#  'APm': -1.0,
#  'APl': 0.8695527,
#  'ARmax1': 0.88090277,
#  'ARmax10': 0.8980903,
#  'ARmax100': 0.8980903,
#  'ARs': -1.0,
#  'ARm': -1.0,
#  'ARl': 0.8980903,
#  'AP_/option1': 0.69825244,
#  'AP_/option2': 0.88044554,
#  'AP_/option3': 0.89713126,
#  'AP_/option4': 0.81905943,
#  'AP_/punch': 0.90759075,
#  'AP_/thumb': 0.92245877,
#  'AP_/ok': 0.9084653,
#  'AP_/back': 0.9229986}

# %%
lite3_results = lite3.evaluate(test_data, batch_size=4)
lite3_results
# Out:
# 20/20 [==============================] - 7s 196ms/step
# {'AP': 0.863767,
#  'AP50': 0.9488871,
#  'AP75': 0.9473072,
#  'APs': -1.0,
#  'APm': -1.0,
#  'APl': 0.8637988,
#  'ARmax1': 0.875,
#  'ARmax10': 0.90125,
#  'ARmax100': 0.90125,
#  'ARs': -1.0,
#  'ARm': -1.0,
#  'ARl': 0.90125,
#  'AP_/option1': 0.6926246,
#  'AP_/option2': 0.8728021,
#  'AP_/option3': 0.91400284,
#  'AP_/option4': 0.8374487,
#  'AP_/punch': 0.8712871,
#  'AP_/thumb': 0.9346063,
#  'AP_/ok': 0.8497638,
#  'AP_/back': 0.9376008}

# %%
lite4_results = lite4.evaluate(test_data, batch_size=2)
lite4_results
# Out:
# 40/40 [==============================] - 8s 116ms/step
# {'AP': 0.87388265,
#  'AP50': 0.95074505,
#  'AP75': 0.94710094,
#  'APs': -1.0,
#  'APm': -1.0,
#  'APl': 0.87419176,
#  'ARmax1': 0.88875,
#  'ARmax10': 0.91375,
#  'ARmax100': 0.91375,
#  'ARs': -1.0,
#  'ARm': -1.0,
#  'ARl': 0.91375,
#  'AP_/option1': 0.73187566,
#  'AP_/option2': 0.89383084,
#  'AP_/option3': 0.9297305,
#  'AP_/option4': 0.75427866,
#  'AP_/punch': 0.9247903,
#  'AP_/thumb': 0.9393666,
#  'AP_/ok': 0.9440865,
#  'AP_/back': 0.8731023}

# %% [markdown]
# **Step 5. Visualization**
#
# Now that we are done with training and evaluation, let us visualise the results we have obtained in forms of tables and figures.

# %%
# add the name of each model to the results
lite0_results['name'] = 'EfficientNet-Lite0'
lite1_results['name'] = 'EfficientNet-Lite1'
lite2_results['name'] = 'EfficientNet-Lite2'
lite3_results['name'] = 'EfficientNet-Lite3'
lite4_results['name'] = 'EfficientNet-Lite4'

# %%
# create a dataframe from the results of each model training
df_results = pd.DataFrame([lite0_results,
              lite1_results,
              lite2_results,
              lite3_results,
              lite4_results])

cols = df_results.columns.tolist()
cols = cols[-1:] + cols[:-1]
df_results = df_results[cols]
df_results = df_results.sort_values(by='AP')
cols_to_show = cols[0:4] + cols[-8:]
df_results[cols_to_show]
# Out:
#                  name        AP      AP50      AP75  AP_/option1  AP_/option2  \
# 0  EfficientNet-Lite0  0.825286  0.941674  0.914654     0.708798     0.852636
# 1  EfficientNet-Lite1  0.833719  0.938586  0.925580     0.683847     0.880741
# 3  EfficientNet-Lite3  0.863767  0.948887  0.947307     0.692625     0.872802
# 2  EfficientNet-Lite2  0.869550  0.956028  0.952970     0.698252     0.880446
# 4  EfficientNet-Lite4  0.873883  0.950745  0.947101     0.731876     0.893831
#
#    AP_/option3  AP_/option4  AP_/punch  AP_/thumb    AP_/ok  AP_/back
# 0     0.902165     0.773388   0.893846   0.819058  0.752663  0.899737
# 1     0.903300     0.719720   0.880427   0.880657  0.803157  0.917905
# 3     0.914003     0.837449   0.871287   0.934606  0.849764  0.937601
# 2     0.897131     0.819059   0.907591   0.922459  0.908465  0.922999
# 4     0.929730     0.754279   0.924790   0.939367  0.944086  0.873102

# %%
colors=mcp.gen_color(cmap="flare_r",n=5)
print(colors)
# Out:
# ['#4b2362', '#873171', '#c24167', '#e5725f', '#edb081']

# %% [markdown]
# ### Plot the Testing mAP

# %%
plt.figure(figsize=(10,5))
sns.set_style('ticks')
ax = sns.barplot(y=df_results.name, x=df_results.AP, palette = "flare_r", saturation = 1.0)
plt.title('\nAP of Models\n', fontsize=22, weight='bold', loc='left')
ax.set_frame_on(False)
ax.set_xticks([])
plt.ylabel('')
plt.xlabel('')

plt.yticks(fontsize=13)
j = 0
for i in ax.patches:
    width, height = i.get_width(), i.get_height()
    x, y = i.get_xy() 
    ax.annotate(f'{round(width*100,2)}%', (x + width+0.035, y + height*0.55), ha='center', fontsize=12, color=colors[j], weight='bold')#, weight='bold')
    j += 1
plt.show()

# %%
model.export(export_dir='.')

# %%
df_results
# Out:
#                  name        AP      AP50      AP75  APs  APm       APl  \
# 0  EfficientNet-Lite0  0.825286  0.941674  0.914654 -1.0 -1.0  0.825358
# 1  EfficientNet-Lite1  0.833719  0.938586  0.925580 -1.0 -1.0  0.833751
# 3  EfficientNet-Lite3  0.863767  0.948887  0.947307 -1.0 -1.0  0.863799
# 2  EfficientNet-Lite2  0.869550  0.956028  0.952970 -1.0 -1.0  0.869553
# 4  EfficientNet-Lite4  0.873883  0.950745  0.947101 -1.0 -1.0  0.874192
#
#      ARmax1  ARmax10  ARmax100  ...  ARm      ARl  AP_/option1  AP_/option2  \
# 0  0.826250  0.88500   0.88500  ... -1.0  0.88500     0.708798     0.852636
# 1  0.841250  0.88000   0.88000  ... -1.0  0.88000     0.683847     0.880741
# 3  0.875000  0.90125   0.90125  ... -1.0  0.90125     0.692625     0.872802
# 2  0.880903  0.89809   0.89809  ... -1.0  0.89809     0.698252     0.880446
# 4  0.888750  0.91375   0.91375  ... -1.0  0.91375     0.731876     0.893831
#
#    AP_/option3  AP_/option4  AP_/punch  AP_/thumb    AP_/ok  AP_/back
# 0     0.902165     0.773388   0.893846   0.819058  0.752663  0.899737
# 1     0.903300     0.719720   0.880427   0.880657  0.803157  0.917905
# 3     0.914003     0.837449   0.871287   0.934606  0.849764  0.937601
# 2     0.897131     0.819059   0.907591   0.922459  0.908465  0.922999
# 4     0.929730     0.754279   0.924790   0.939367  0.944086  0.873102
#
# [5 rows x 21 columns]

# %% [markdown]
# **Step 6.  Export as a TensorFlow Lite model.**
#
# Export the trained object detection model to the TensorFlow Lite format by specifying which folder you want to export the quantized model to. The default post-training quantization technique is full integer quantization.

# %%
lite0.export(export_dir='your_path/data_for_object_detection/tflite/lite0/', export_format=[ExportFormat.TFLITE, ExportFormat.LABEL])

# %%
lite1.export(export_dir='your_path/data_for_object_detection/tflite/lite1/', export_format=[ExportFormat.TFLITE])

# %%
lite2.export(export_dir='your_path/data_for_object_detection/tflite/lite2/', export_format=[ExportFormat.TFLITE])

# %%
lite3.export(export_dir='your_path/data_for_object_detection/tflite/lite3/', export_format=[ExportFormat.TFLITE])

# %%
lite4.export(export_dir='your_path/data_for_object_detection/tflite/lite4/', export_format=[ExportFormat.TFLITE])

# %%
# path to the exported tflite model
model_path = 'your_path/data_for_object_detection/tflite/lite0/model.tflite'

# %%
#@title Load the trained TFLite model for infering custom images

import cv2
from PIL import Image

# Load the labels into a list
classes = ['???'] * lite0.model_spec.config.num_classes
label_map = lite0.model_spec.config.label_map
for label_id, label_name in label_map.as_dict().items():
  classes[label_id-1] = label_name

# Define a list of colors for visualization
COLORS = np.random.randint(0, 255, size=(len(classes), 3), dtype=np.uint8)

def preprocess_image(image_path, input_size):
  """Preprocess the input image to feed to the TFLite model"""
  img = tf.io.read_file(image_path)
  img = tf.io.decode_image(img, channels=3)
  img = tf.image.convert_image_dtype(img, tf.uint8)
  original_image = img
  resized_img = tf.image.resize(img, input_size)
  resized_img = resized_img[tf.newaxis, :]
  resized_img = tf.cast(resized_img, dtype=tf.uint8)
  return resized_img, original_image


def detect_objects(interpreter, image, threshold):
  """Returns a list of detection results, each a dictionary of object info."""

  signature_fn = interpreter.get_signature_runner()

  # Feed the input image to the model
  output = signature_fn(images=image)

  # Get all outputs from the model
  count = int(np.squeeze(output['output_0']))
  scores = np.squeeze(output['output_1'])
  classes = np.squeeze(output['output_2'])
  boxes = np.squeeze(output['output_3'])

  results = []
  for i in range(count):
    if scores[i] >= threshold:
      result = {
        'bounding_box': boxes[i],
        'class_id': classes[i],
        'score': scores[i]
      }
      results.append(result)
  return results


def run_odt_and_draw_results(image_path, interpreter, threshold=0.5):
  """Run object detection on the input image and draw the detection results"""
  # Load the input shape required by the model
  _, input_height, input_width, _ = interpreter.get_input_details()[0]['shape']

  # Load the input image and preprocess it
  preprocessed_image, original_image = preprocess_image(
      image_path,
      (input_height, input_width)
    )

  # Run object detection on the input image
  results = detect_objects(interpreter, preprocessed_image, threshold=threshold)

  # Plot the detection results on the input image
  original_image_np = original_image.numpy().astype(np.uint8)
  for obj in results:
    # Convert the object bounding box from relative coordinates to absolute
    # coordinates based on the original image resolution
    ymin, xmin, ymax, xmax = obj['bounding_box']
    xmin = int(xmin * original_image_np.shape[1])
    xmax = int(xmax * original_image_np.shape[1])
    ymin = int(ymin * original_image_np.shape[0])
    ymax = int(ymax * original_image_np.shape[0])

    # Find the class index of the current object
    class_id = int(obj['class_id'])

    # Draw the bounding box and label on the image
    color = [int(c) for c in COLORS[class_id]]
    cv2.rectangle(original_image_np, (xmin, ymin), (xmax, ymax), color, 2)
    # Make adjustments to make the label visible for all objects
    y = ymin - 15 if ymin - 15 > 15 else ymin + 15
    label = "{}: {:.0f}%".format(classes[class_id], obj['score'] * 100)
    cv2.putText(original_image_np, label, (xmin, y),
        cv2.FONT_HERSHEY_SIMPLEX, 0.5, color, 2)

  # Return the final image
  original_uint8 = original_image_np.astype(np.uint8)
  return original_uint8

# %%
#@title Run object detection on custom image
import requests
from io import BytesIO
from PIL import Image

INPUT_IMAGE_URL = "https://c8.alamy.com/comp/2ARWCER/male-hand-with-raised-index-finger-on-white-background-2ARWCER.jpg" #@param {type:"string"}
DETECTION_THRESHOLD = 0.3 #@param {type:"number"}

TEMP_FILE = 'F:/Downloads/img.png'

#!wget -q -O $TEMP_FILE $INPUT_IMAGE_URL
response = requests.get(INPUT_IMAGE_URL)
im = Image.open(BytesIO(response.content))
#im = Image.open(TEMP_FILE)
im.thumbnail((512, 512), Image.ANTIALIAS)
im.save(TEMP_FILE, 'PNG')

# Load the TFLite model
interpreter = tf.lite.Interpreter(model_path=model_path)
interpreter.allocate_tensors()

# Run inference and draw detection result on the local copy of the original file
detection_result_image = run_odt_and_draw_results(
    TEMP_FILE,
    interpreter,
    threshold=DETECTION_THRESHOLD
)

# Show the detection result
Image.fromarray(detection_result_image)
# Out:
# <PIL.Image.Image image mode=RGB size=339x512>

# %% [markdown]
# ## Additional Information
#
# ---
#
#
# ### Customize the EfficientDet model hyperparameters
#
# The model and training pipline parameters you can adjust are:
#
# * `model_dir`: The location to save the model checkpoint files. If not set, a temporary directory will be used.
# * `steps_per_execution`: Number of steps per training execution.
# * `moving_average_decay`: Float. The decay to use for maintaining moving averages of the trained parameters.
# * `var_freeze_expr`: The regular expression to map the prefix name of variables to be frozen which means remaining the same during training. More specific, use `re.match(var_freeze_expr, variable_name)` in the codebase to map the variables to be frozen.
# * `tflite_max_detections`: integer, 25 by default. The max number of output detections in the TFLite model.
# * `strategy`:  A string specifying which distribution strategy to use. Accepted values are 'tpu', 'gpus', None. tpu' means to use TPUStrategy. 'gpus' mean to use MirroredStrategy for multi-gpus. If None, use TF default with OneDeviceStrategy.
# * `tpu`:  The Cloud TPU to use for training. This should be either the name used when creating the Cloud TPU, or a grpc://ip.address.of.tpu:8470 url.
# * `use_xla`: Use XLA even if strategy is not tpu. If strategy is tpu, always use XLA, and this flag has no effect.
# * `profile`: Enable profile mode.
# * `debug`: Enable debug mode.
#
# Other parameters that can be adjusted is shown in [hparams_config.py](https://github.com/google/automl/blob/df451765d467c5ed78bbdfd632810bc1014b123e/efficientdet/hparams_config.py#L170).
#
#
# For instance, you can set the `var_freeze_expr='efficientnet'` which freezes the variables with name prefix `efficientnet` (default is `'(efficientnet|fpn_cells|resample_p6)'`). This allows the model to freeze untrainable variables and keep their value the same through training.
#
# ```python
# spec = model_spec.get('efficientdet_lite0')
# spec.config.var_freeze_expr = 'efficientnet'
# ```

# %% [markdown]
# ### Customize Post-training quantization on the TensorFlow Lite model
#
# [Post-training quantization](https://www.tensorflow.org/lite/performance/post_training_quantization) is a conversion technique that can reduce model size and inference latency, while also improving CPU and hardware accelerator inference speed, with a little degradation in model accuracy. Thus, it's widely used to optimize the model.
#
# Model Maker library applies a default post-training quantization techique when exporting the model. If you want to customize post-training quantization, Model Maker supports multiple post-training quantization options using [QuantizationConfig](https://www.tensorflow.org/lite/api_docs/python/tflite_model_maker/config/QuantizationConfig) as well. Let's take float16 quantization as an instance. First, define the quantization config.
#
# ```python
# config = QuantizationConfig.for_float16()
# ```
#
#
# Then we export the TensorFlow Lite model with such configuration.
#
# ```python
# model.export(export_dir='.', tflite_filename='model_fp16.tflite', quantization_config=config)
# ```

# %% [markdown]
# # Read more
#
# You can read our [object detection](https://www.tensorflow.org/lite/examples/object_detection/overview) example to learn technical details. For more information, please refer to:
#
# *   TensorFlow Lite Model Maker [guide](https://www.tensorflow.org/lite/models/modify/model_maker) and [API reference](https://www.tensorflow.org/lite/api_docs/python/tflite_model_maker).
# *   Task Library: [ObjectDetector](https://www.tensorflow.org/lite/inference_with_metadata/task_library/object_detector) for deployment.
# *   The end-to-end reference apps: [Android](https://github.com/tensorflow/examples/tree/master/lite/examples/object_detection/android), [iOS](https://github.com/tensorflow/examples/tree/master/lite/examples/object_detection/ios), and [Raspberry PI](https://github.com/tensorflow/examples/tree/master/lite/examples/object_detection/raspberry_pi).
